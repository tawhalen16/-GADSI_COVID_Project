# %% [markdown]
# With a large dataset of tweets and a wide range of possible cities, we wanted to confirm that cities on people's accounts matched a list of all cities in the United States.

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 1000)

# %%
df = pd.read_csv('./combined_us.csv')
cities = pd.read_csv('./USA-cities-and-states/us_cities_states_counties.csv', sep = '|')

# %%
df
# Out:
#                   status_id             user_id                 created_at  \
# 0       1255648063143710723            92677101  2020-04-30 00:00:01+00:00
# 1       1255648072090169345           217987384  2020-04-30 00:00:03+00:00
# 2       1255648079790903297            62657173  2020-04-30 00:00:05+00:00
# 3       1255648164809445382  988863378427990017  2020-04-30 00:00:25+00:00
# 4       1255648197835251713           475393715  2020-04-30 00:00:33+00:00
# ...                     ...                 ...                        ...
# 155374  1244413925912907778           160304538  2020-03-29 23:59:34+00:00
# 155375  1244413952945250305  862769187499986944  2020-03-29 23:59:41+00:00
# 155376  1244413955172372481            80139649  2020-03-29 23:59:41+00:00
# 155377  1244414009736118277            32232449  2020-03-29 23:59:54+00:00
# 155378  1244414009329082368           113628427  2020-03-29 23:59:54+00:00
#
#             screen_name                                               text  \
# 0           lopezgovlaw  #SurveySunday: Most Miamians Think #Coronaviru...
# 1         maisondecorla  *Breaking News* This just in - Stonewall Kitch...
# 2           drosssports  Once again, while it wasn’t @DrDavidKatz , @to...
# 3            prana_mani  Free #webinar announcement! This Sunday, May 3...
# 4            KPobgyndoc  Went on a #COVID19 walk with my #mentor on her...
# ...                 ...                                                ...
# 155374        iskandrah  I don't know who needs to hear this, but #coro...
# 155375  Customer_Effort  Trying my #comfilife #coccyx #cushion #sciatic...
# 155376  rickeybevington  I am surprised too &gt; “Local leaders and som...
# 155377   djfenixchicago  Another 30! #socialdistancing #coronavirus #co...
# 155378         isamh195  #Covid_19 relief. Better things to talk about ...
#
#                      source  is_quote  is_retweet  favourites_count  \
# 0        Twitter for iPhone     False       False              8132
# 1                 Instagram     False       False                67
# 2        Twitter for iPhone      True       False             38651
# 3        Twitter for iPhone     False       False               159
# 4        Twitter for iPhone     False       False              6336
# ...                     ...       ...         ...               ...
# 155374  Twitter for Android     False       False            171376
# 155375   Twitter for iPhone     False       False                95
# 155376     Twitter for iPad      True       False             15021
# 155377  Twitter for Android     False       False              1077
# 155378  Twitter for Android     False       False               244
#
#         retweet_count  ...  place_full_name place_type followers_count  \
# 0                   2  ...        Miami, FL       city           16007
# 1                   0  ...       Boutte, LA       city             105
# 2                   0  ...      Chicago, IL       city            6441
# 3                   1  ...         Troy, NY       city              23
# 4                   2  ...      Oakland, CA       city            7161
# ...               ...  ...              ...        ...             ...
# 155374              4  ...    Illinois, USA      admin           18163
# 155375              0  ...   Minnesota, USA      admin              29
# 155376              1  ...      Atlanta, GA       city            4199
# 155377              0  ...      Chicago, IL       city             819
# 155378              0  ...  Albuquerque, NM       city             131
#
#         friends_count         account_created_at verified  lang is_reply  \
# 0                3634  2009-11-26 03:42:10+00:00     True    en    False
# 1                 146  2010-11-21 03:03:54+00:00    False    en    False
# 2                 501  2009-08-03 23:44:39+00:00     True    en    False
# 3                  93  2018-04-24 19:32:56+00:00    False    en    False
# 4                6670  2012-01-27 00:49:58+00:00    False    en    False
# ...               ...                        ...      ...   ...      ...
# 155374           7695  2010-06-27 20:18:34+00:00     True    en    False
# 155375             48  2017-05-11 20:39:38+00:00    False    en    False
# 155376           1858  2009-10-05 22:12:28+00:00    False    en    False
# 155377            217  2009-04-17 01:00:08+00:00    False    en    False
# 155378            372  2010-02-12 13:17:24+00:00    False    en    False
#
#                city state
# 0             Miami    FL
# 1            Boutte    LA
# 2           Chicago    IL
# 3              Troy    NY
# 4           Oakland    CA
# ...             ...   ...
# 155374  unspecified    IL
# 155375  unspecified    MN
# 155376      Atlanta    GA
# 155377      Chicago    IL
# 155378  Albuquerque    NM
#
# [155379 rows x 21 columns]

# %%
cities
# Out:
#               City State short   State full                 County  \
# 0       Holtsville          NY     New York                SUFFOLK
# 1       Holtsville          NY     New York                SUFFOLK
# 2         Adjuntas          PR  Puerto Rico               ADJUNTAS
# 3         Adjuntas          PR  Puerto Rico               ADJUNTAS
# 4         Adjuntas          PR  Puerto Rico               ADJUNTAS
# ...            ...         ...          ...                    ...
# 63206      Klawock          AK       Alaska  PRINCE OF WALES HYDER
# 63207   Metlakatla          AK       Alaska  PRINCE OF WALES HYDER
# 63208  Point Baker          AK       Alaska  PRINCE OF WALES HYDER
# 63209    Ward Cove          AK       Alaska      KETCHIKAN GATEWAY
# 63210     Wrangell          AK       Alaska               WRANGELL
#
#                      City alias
# 0      Internal Revenue Service
# 1                    Holtsville
# 2               URB San Joaquin
# 3              Jard De Adjuntas
# 4           Colinas Del Gigante
# ...                         ...
# 63206                   Klawock
# 63207                Metlakatla
# 63208               Point Baker
# 63209                 Ward Cove
# 63210                  Wrangell
#
# [63211 rows x 5 columns]

# %% [markdown]
# The cities dataset contains a list of every city, state, county, and many alternative city names in the United States. The dataset was put together by grammakov and can be found unaltered on their [github](https://github.com/grammakov/USA-cities-and-states)

# %%
city = list(cities['City'])
city = list(set(city))

# %%
del city[0]

# %%
df_c = list(df['city'])
df_c = list(set(df_c))

# %% [markdown]
# Each list or column of city names was converted to a set in order to compare overlapping city names without taking up an immense amount of time iterating over hundred or thousands of duplicates.

# %%
len(df_c)
# Out:
# 5628

# %% [markdown]
# There were 5628 unique city names used in our twitter dataset.

# %%
# https://medium.com/better-programming/a-visual-guide-to-set-comparisons-in-python-6ab7edb9ec41
inter = set(df_c).intersection(set(city))

# %%
inter
# Out:
# {'Delray Beach',
#  'Bath',
#  'Lemoyne',
#  'Redford',
#  'Jupiter',
#  'Chalmette',
#  'Port Lavaca',
#  'Altadena',
#  'Mukilteo',
#  'Mendota',
#  'Litchfield Park',
#  'Southbridge',
#  'Thatcher',
#  'Lake Elsinore',
#  'Oxford',
#  'Wellington',
#  'Biddeford',
#  'Shelbyville',
#  'Port Chester',
#  'Pepperell',
#  'Lamar',
#  'Windham',
#  'Roanoke',
#  'Herculaneum',
#  'Wellesley',
#  'Hemet',
#  'Marietta',
#  'Elizabeth',
#  'Hagerstown',
#  'Dryden',
#  'South Elgin',
#  'Sunland Park',
#  'Westport',
#  'Mountain Home',
#  'Sunset Beach',
#  'Redan',
#  'Groveport',
#  'Hurricane',
#  'Ipswich',
#  'Muldraugh',
#  'North Palm Beach',
#  'Selinsgrove',
#  'Port Salerno',
#  'South Sioux City',
#  'Goshen',
#  'Lynwood',
#  'Harrisonburg',
#  'Bayville',
#  'Justice',
#  'Syracuse',
#  'Suffolk',
#  'Fernandina Beach',
#  'Chino',
#  'Three Oaks',
#  'Santa Cruz',
#  'Addison',
#  'Severn',
#  'Pelham',
#  'Pine Island',
#  'Reisterstown',
#  'Hanover',
#  'Weslaco',
#  'Crown Point',
#  'Picayune',
#  'Howard',
#  'Pflugerville',
#  'Swansea',
#  'Wyncote',
#  'Brackenridge',
#  'Granger',
#  'Galt',
#  'San Leandro',
#  'Los Fresnos',
#  'Leicester',
#  'Thiells',
#  'Midlothian',
#  'Pottstown',
#  'Prairie View',
#  'Tomah',
#  'Powell',
#  'Valley Falls',
#  'East Petersburg',
#  'Greenville',
#  'Darien',
#  'Dennis Port',
#  'Hoboken',
#  'Riverbank',
#  'Charles Town',
#  'Islip Terrace',
#  'Beloit',
#  'South Bend',
#  'Hazleton',
#  'Enfield',
#  'Torrance',
#  'Fountain Hills',
#  'Elkridge',
#  'Allouez',
#  'Pekin',
#  'Mayfield',
#  'Pluckemin',
#  'Oakton',
#  'Flowood',
#  'Woodridge',
#  'West Monroe',
#  'Owensboro',
#  'Logansport',
#  'Lexington',
#  'Cross Plains',
#  'Sun City Center',
#  'Rio Rico',
#  'Bartow',
#  'Gresham',
#  'Antelope',
#  'Minnetonka',
#  'Pawcatuck',
#  'Endwell',
#  'Hiram',
#  'Elim',
#  'Mora',
#  'Downers Grove',
#  'Pullman',
#  'West Haven',
#  'Vernon',
#  'Mattapoisett',
#  'Gold Canyon',
#  'Haines City',
#  'Show Low',
#  'Yucaipa',
#  'Shawano',
#  'Poughkeepsie',
#  'Cartersville',
#  'Bellmawr',
#  'Perris',
#  'Pleasant Grove',
#  'Murphysboro',
#  'Westborough',
#  'Redwood City',
#  'Verona',
#  'Cherry Hill',
#  'Foley',
#  'Bastrop',
#  'River Grove',
#  'Bell Gardens',
#  'Gridley',
#  'Lenoir City',
#  'Joliet',
#  'Stirling',
#  'Carpentersville',
#  'Escalon',
#  'Logan',
#  'Newton',
#  'Richmond Hill',
#  'La Crosse',
#  'Frackville',
#  'Freer',
#  'Arlington Heights',
#  'Friendswood',
#  'Deerfield',
#  'Edina',
#  'Savoy',
#  'Kapolei',
#  'San Marcos',
#  'Eleanor',
#  'West Palm Beach',
#  'Cedar Falls',
#  'Cape Neddick',
#  'Red Wing',
#  'Hilton Head Island',
#  'Skaneateles',
#  'Hampton',
#  'Dumont',
#  'Center Moriches',
#  'Cortland',
#  'Mecca',
#  'Lambertville',
#  'Carefree',
#  'Helena',
#  'Arcata',
#  'Belmar',
#  'Pembroke',
#  'Scarborough',
#  'Owasso',
#  'Sun City West',
#  'Creedmoor',
#  'Solvang',
#  'Beltsville',
#  'Mauldin',
#  'Hallsville',
#  'Dracut',
#  'Sumter',
#  'Jonestown',
#  'Soledad',
#  'Ontario',
#  'White River Junction',
#  'Rockledge',
#  'Haverstraw',
#  'Glen Cove',
#  'Lima',
#  'Fishers',
#  'Denville',
#  'Wesley Chapel',
#  'Marlboro',
#  'Palm Coast',
#  'Broadview Heights',
#  'Mesquite',
#  'Elkton',
#  'Bay City',
#  'Bettendorf',
#  'Anniston',
#  'Hillview',
#  'Granite Quarry',
#  'Lodi',
#  'Chesterland',
#  'West Bend',
#  'Vacaville',
#  'Daphne',
#  'Moab',
#  'Fulton',
#  'North Salt Lake',
#  'Mount Orab',
#  'Linwood',
#  'Pinole',
#  'Sylva',
#  'Calistoga',
#  'Sheboygan',
#  'Hebron',
#  'Tabernacle',
#  'Adelanto',
#  'Montpelier',
#  'Bordentown',
#  'Hastings',
#  'Prosper',
#  'Elburn',
#  'Southington',
#  'Carrizo Springs',
#  'Natick',
#  'Addis',
#  'Helmetta',
#  'Port Wentworth',
#  'Annville',
#  'Fort Montgomery',
#  'Elkhorn',
#  'Batesburg',
#  'Boardman',
#  'Paia',
#  'Cranberry',
#  'Uxbridge',
#  'Monona',
#  'Chehalis',
#  'Centerville',
#  'Nicholasville',
#  'Bethany',
#  'Lone Tree',
#  'Fairland',
#  'Orland Park',
#  'Edwards',
#  'Cottonwood',
#  'Lansdowne',
#  'Prairie Village',
#  'Forestdale',
#  'Wayland',
#  'Clarksburg',
#  'Livermore',
#  'Glen Allen',
#  'Versailles',
#  'Bronx',
#  'Merrimac',
#  'Fort Lauderdale',
#  'Fox Island',
#  'Adrian',
#  'Middlesex',
#  'Crystal City',
#  'Franklin Lakes',
#  'Montebello',
#  'Crestview',
#  'Torrington',
#  'Falcon Heights',
#  'Cameron',
#  'Fayetteville',
#  'Cave Springs',
#  'Brigantine',
#  'Holliston',
#  'Bakersfield',
#  'Tewksbury',
#  'Fergus Falls',
#  'Bohemia',
#  'Caldwell',
#  'Millbury',
#  'Keller',
#  'Indialantic',
#  'Brockton',
#  'Lynn Haven',
#  'La Grande',
#  'Papillion',
#  'Shafter',
#  'Palmdale',
#  'West Point',
#  'Siloam Springs',
#  'Friendly',
#  'Indiantown',
#  'Arkadelphia',
#  'Fishkill',
#  'Shiloh',
#  'Springfield',
#  'Bensenville',
#  'Dixon',
#  'Basalt',
#  'Albany',
#  'La Habra',
#  'Lannon',
#  'Bonita Springs',
#  'Bloomfield',
#  'West Hartford',
#  'Old Orchard Beach',
#  'Sergeant Bluff',
#  'Winooski',
#  'Markham',
#  'South Lebanon',
#  'Goldenrod',
#  'Bixby',
#  'Idaho Falls',
#  'Waterville',
#  'Northport',
#  'Cohasset',
#  'Rancho Santa Margarita',
#  'Winter Park',
#  'Manlius',
#  'Whitsett',
#  'Ferndale',
#  'Tavernier',
#  'Hartland',
#  'Bayfield',
#  'Corpus Christi',
#  'Montville',
#  'Red Bank',
#  'Asbury Park',
#  'Longmont',
#  'Pickerington',
#  'Covington',
#  'Beeville',
#  'Hartwell',
#  'Holton',
#  'Mount Ephraim',
#  'Arvada',
#  'Shavertown',
#  'Pembroke Pines',
#  'East Providence',
#  'Mandan',
#  'Red Bud',
#  'Bonita',
#  'Morehead City',
#  'Northfield',
#  'Venice',
#  'Miamisburg',
#  'Zionsville',
#  'Woodside',
#  'Avenel',
#  'Garden Grove',
#  'Milan',
#  'Decatur',
#  'Barberton',
#  'Jasper',
#  'Narrows',
#  'Durham',
#  'Port Washington',
#  'Westville',
#  'Clayton',
#  'Corinth',
#  'Lake Zurich',
#  'Burbank',
#  'Brookville',
#  'Lily',
#  'Wilton',
#  'Marlborough',
#  'La Plata',
#  'Waukesha',
#  'Del Rio',
#  'Ballwin',
#  'Clifton Heights',
#  'Princeton Junction',
#  'Northbridge',
#  'Painesville',
#  'Boaz',
#  'Swartz',
#  'Panama City',
#  'Kenosha',
#  'Sanibel',
#  'Dardanelle',
#  'Tanner',
#  'Malakoff',
#  'Keene',
#  'Rocklin',
#  'Winona',
#  'Andover',
#  'Sharon',
#  'Grand Island',
#  'Cayce',
#  'Kenner',
#  'Oklahoma City',
#  'Ross',
#  'Cranford',
#  'New Caney',
#  'Wakefield',
#  'Royse City',
#  'Hubbard',
#  'Whiteland',
#  'Starkville',
#  'Cape Canaveral',
#  'Lake Alfred',
#  'Homer',
#  'Riverdale',
#  'Trumbull',
#  'Ocean Shores',
#  'Wilkesboro',
#  'Northbrook',
#  'Kentfield',
#  'Hermiston',
#  'Vermillion',
#  'Bedford',
#  'Mount Airy',
#  'Southlake',
#  'La Joya',
#  'Wanaque',
#  'Labadieville',
#  'Ithaca',
#  'Indiana',
#  'Cresskill',
#  'Poland',
#  'Bayside',
#  'Lubbock',
#  'Eden',
#  'Cleveland',
#  'Faribault',
#  'Rocky River',
#  'Belle Mead',
#  'Somerset',
#  'Vallejo',
#  'Wrightsboro',
#  'Benton Harbor',
#  'Grand Haven',
#  'Nanuet',
#  'Brazil',
#  'Montgomeryville',
#  'Alabaster',
#  'Lisle',
#  'Swepsonville',
#  'Pendleton',
#  'Gladstone',
#  'Sea Isle City',
#  'Huntington Woods',
#  'Wyoming',
#  'Crawfordsville',
#  'Denison',
#  'Waianae',
#  'Clio',
#  'Edison',
#  'Hutchinson',
#  'Richardson',
#  'Barnhart',
#  'Swampscott',
#  'Half Moon Bay',
#  'East Greenbush',
#  'Lake Jackson',
#  'Boonville',
#  'Knightdale',
#  'Essex Fells',
#  'New Philadelphia',
#  'Pawtucket',
#  'Harvey',
#  'Somerville',
#  'Broadview',
#  'Mojave',
#  'Mechanicsville',
#  'Conklin',
#  'Goodyear',
#  'Key West',
#  'Lakeview',
#  'Flushing',
#  'Enola',
#  'Sanger',
#  'Ogden',
#  'Naugatuck',
#  'Mantorville',
#  'Churchville',
#  'Randallstown',
#  'Belle Glade',
#  'Hartsdale',
#  'Hyattsville',
#  'Sahuarita',
#  'French Camp',
#  'Miramar Beach',
#  'Cherryville',
#  'Highland Park',
#  'Artesia',
#  'Tilton',
#  'Pontotoc',
#  'Crittenden',
#  'East Palestine',
#  'Melbourne Beach',
#  'Holtsville',
#  'Guthrie',
#  'Elk River',
#  'Strasburg',
#  'University Park',
#  'Cincinnati',
#  'La Grange',
#  'Trenton',
#  'Cathedral City',
#  'York Harbor',
#  'Glen Ridge',
#  'Sterling',
#  'Melville',
#  'Poteau',
#  'North Port',
#  'Loganville',
#  'Commerce City',
#  'Triangle',
#  'Kirksville',
#  'Wautoma',
#  'Loveland',
#  'Ada',
#  'Calexico',
#  'North East',
#  'Milpitas',
#  'Miles City',
#  'Kohler',
#  'Ellwood City',
#  'Jena',
#  'Nederland',
#  'Gulf Shores',
#  'Chatsworth',
#  'Blaine',
#  'Manteca',
#  'Patchogue',
#  'Bridgeton',
#  'Valley Cottage',
#  'Littleton',
#  'Grandville',
#  'New Smyrna Beach',
#  'Riverview',
#  'Murfreesboro',
#  'High Ridge',
#  'Pasadena',
#  'Silver Spring',
#  'Thomasville',
#  'Gainesville',
#  'Sharon Hill',
#  'Newington',
#  'Tomball',
#  'Shannon',
#  'Port Reading',
#  'Oak Forest',
#  'Colusa',
#  'Rockville Centre',
#  'Pittsfield',
#  'Marina',
#  'Glenpool',
#  'Monticello',
#  'Lansford',
#  'Mount Sinai',
#  'Olmsted Falls',
#  'Moulton',
#  'North Aurora',
#  'Calumet City',
#  'Kissimmee',
#  'Newport Beach',
#  'Hadley',
#  'Santa Ynez',
#  'Michigan Center',
#  'Roanoke Rapids',
#  'Como',
#  'Jonesboro',
#  'Eagan',
#  'Deltona',
#  'Lewes',
#  'Titusville',
#  'Soldier',
#  'Fort Payne',
#  'Thomaston',
#  'Florence',
#  'Ridgefield',
#  'Old Bethpage',
#  'Cookeville',
#  'Boutte',
#  'Zebulon',
#  'Moses Lake',
#  'Manitou Springs',
#  'Sudbury',
#  'Clarcona',
#  'Sebastopol',
#  'Zachary',
#  'Denver',
#  'Highland Lake',
#  'Libertyville',
#  'Port Charlotte',
#  'Hayden',
#  'Lake Katrine',
#  'York',
#  'Devon',
#  'Turners Falls',
#  'Jericho',
#  'Great Bend',
#  'Grafton',
#  'Bradley Beach',
#  'North Fort Myers',
#  'Grace',
#  'Crestwood',
#  'Immokalee',
#  'Cushing',
#  'Monmouth Beach',
#  'East Falmouth',
#  'Klamath Falls',
#  'Lake Hopatcong',
#  'Wichita',
#  'Fairdale',
#  'Middlebury',
#  'Fraser',
#  'Tarboro',
#  'Kenilworth',
#  'Rancho Cordova',
#  'Dundalk',
#  'Greeley',
#  'Eastlake',
#  'South Carver',
#  'Laguna',
#  'Neenah',
#  'Mountlake Terrace',
#  'Tolland',
#  'Maumelle',
#  'Dublin',
#  'Fair Oaks',
#  'Laramie',
#  'Waretown',
#  'Pine Grove Mills',
#  'Hermosa Beach',
#  'Gifford',
#  'Lake Worth',
#  'Tarrytown',
#  'Vincent',
#  'Country Club Hills',
#  'Verplanck',
#  'Middle River',
#  'Watertown',
#  'Warner Robins',
#  'Dahlonega',
#  'Union City',
#  'Fairport',
#  'Oronogo',
#  'Kokomo',
#  'Jacksonville Beach',
#  'Woodhaven',
#  'Big Stone Gap',
#  'Clarendon Hills',
#  'Azusa',
#  'Prospect',
#  'Brielle',
#  'Keizer',
#  'Dunn',
#  'Elmwood',
#  'Metuchen',
#  'Tiverton',
#  'Laguna Woods',
#  'Windsor Heights',
#  'University Place',
#  'Ocala',
#  'Whitman',
#  'Cutler',
#  'Cary',
#  'Baltimore',
#  'Waynesville',
#  'Bennettsville',
#  'Cannonsburg',
#  'Pantego',
#  'Deptford',
#  'Arcola',
#  'San Angelo',
#  'Silvis',
#  'Elmira',
#  'Waupun',
#  'Berea',
#  'Muskego',
#  'Loughman',
#  'Piqua',
#  'Crossett',
#  'Hummelstown',
#  'Waialua',
#  'Pawling',
#  'Caribou',
#  'Manchester',
#  'De Witt',
#  'Morgantown',
#  'Umatilla',
#  'Fallon',
#  'Paducah',
#  'Bogota',
#  'Alton',
#  'New Buffalo',
#  'Wailuku',
#  'Edgewood',
#  'Dalton',
#  'Margate City',
#  'Republic',
#  'Seaside Heights',
#  'Hopewell',
#  'Two Rivers',
#  'Melrose Park',
#  'Chattanooga',
#  'Hauppauge',
#  'Mapleton',
#  'Floyds Knobs',
#  'Olympia',
#  'Fort Oglethorpe',
#  'Weston',
#  'Parma',
#  'Mequon',
#  'Stone Mountain',
#  'Lindenhurst',
#  'Roosevelt',
#  'Sturbridge',
#  'Conway',
#  'Pewaukee',
#  'Odenton',
#  'Sarasota',
#  'Modena',
#  'Rowland Heights',
#  'Chickasha',
#  'Thousand Oaks',
#  'Roslyn Heights',
#  'Langhorne',
#  'Plaquemine',
#  'Gloucester',
#  'Amsterdam',
#  'Ronkonkoma',
#  'Cle Elum',
#  'Blacksburg',
#  'Medfield',
#  'Angier',
#  'Philomath',
#  'Robertsville',
#  'Fanwood',
#  'Downey',
#  'Montgomery',
#  'Tuckerton',
#  'Santee',
#  'Aspen',
#  'Northborough',
#  'West Sayville',
#  'Strathmore',
#  'West New York',
#  'Saylorsburg',
#  'Laredo',
#  'Madera',
#  'Alvarado',
#  'West Babylon',
#  'Merrill',
#  'Byfield',
#  'Noblesville',
#  'Peru',
#  'Orangevale',
#  'Remsenburg',
#  'Hallie',
#  'Rahway',
#  'Aubrey',
#  'Nevada',
#  'Brandywine',
#  'Belleview',
#  'West Falmouth',
#  'Cave Spring',
#  'Whitney',
#  'Waunakee',
#  'Ladson',
#  'Huntertown',
#  'Parris Island',
#  'Dexter',
#  'Castle Rock',
#  'Tecumseh',
#  'Sycamore',
#  'Westerville',
#  'Carteret',
#  'Haymarket',
#  'Aptos',
#  'Gastonville',
#  'North Tonawanda',
#  'Point Clear',
#  'Mercer Island',
#  'Thornton',
#  'Colfax',
#  'Cuyahoga Falls',
#  'Wolf Lake',
#  'New Richmond',
#  'Winnetka',
#  'Scottsbluff',
#  'Woodlyn',
#  'Green Valley',
#  'Merrillville',
#  'Albuquerque',
#  'Bridgeport',
#  'Shinnston',
#  'Olivehurst',
#  'Streator',
#  'Moscow',
#  'Cadillac',
#  'The Colony',
#  'South Windsor',
#  'Uniontown',
#  'Champlin',
#  'Kennebunkport',
#  'Hobart',
#  'Pharr',
#  'Scranton',
#  'Eufaula',
#  'Great Barrington',
#  'Struthers',
#  'Brea',
#  'Beavercreek',
#  'Greenacres',
#  'Lakewood',
#  'Picture Rocks',
#  'Locust Grove',
#  'Denton',
#  'Mountain Top',
#  'Terrell',
#  'Seminole',
#  'Clendenin',
#  'Norwalk',
#  'Intercourse',
#  'Plain City',
#  'Crookston',
#  'Fort Walton Beach',
#  'Clarence Center',
#  'Maplewood',
#  'Milledgeville',
#  'Chestertown',
#  'Greenwood',
#  'Lansdale',
#  'Saltillo',
#  'Colonial Beach',
#  'Whitefish',
#  'Hanford',
#  'La Mirada',
#  'Herndon',
#  'Glenolden',
#  'Oregon',
#  'Big Lake',
#  'Madras',
#  'Solana Beach',
#  'Waconia',
#  'Cheraw',
#  'Garnett',
#  'Kapaa',
#  'Secaucus',
#  'Pikesville',
#  'Brownwood',
#  'Marblehead',
#  'Avondale',
#  'Bolivar',
#  'Seven Springs',
#  'Morton',
#  'Voorhees',
#  'Farmersville',
#  'Collegedale',
#  'Sumner',
#  'Ramsey',
#  'Mount Prospect',
#  'Borger',
#  'Hudson',
#  'Denham Springs',
#  'Fruita',
#  'Moorpark',
#  'Buellton',
#  'Cornwall',
#  'Bismarck',
#  'Schriever',
#  'Cypress',
#  'Chesterton',
#  'Brusly',
#  'Tangent',
#  'Tallevast',
#  'Harper Woods',
#  'La Vista',
#  'East Rockaway',
#  'Santa Teresa',
#  'Sandwich',
#  'Concord',
#  'Sound Beach',
#  'Georgetown',
#  'Boise',
#  'Schertz',
#  'Abilene',
#  'Oceanside',
#  'Tallahassee',
#  'Deadwood',
#  'Nelsonville',
#  'Centerport',
#  'Oconomowoc',
#  'Neodesha',
#  'Winfield',
#  'Tifton',
#  'Worth',
#  'Upper Falls',
#  'Orange Park',
#  'Metter',
#  'Lewis Center',
#  'Spearfish',
#  'Urbandale',
#  'Circleville',
#  'Bethalto',
#  'Atlantic City',
#  'Euclid',
#  'Rincon',
#  'Nags Head',
#  'Palm Beach Gardens',
#  'Carlisle',
#  'Carrollton',
#  'Apache Junction',
#  'Whiteville',
#  'Greentown',
#  'Streetsboro',
#  'Luling',
#  'Pottsville',
#  'Paramus',
#  'Montverde',
#  'Eagleville',
#  'New Baltimore',
#  'Hamtramck',
#  'Mahopac',
#  'Auburn',
#  'Palmetto',
#  'Troutdale',
#  'Sugar Grove',
#  'Dacula',
#  'Neptune Beach',
#  'Brimfield',
#  'Mars Hill',
#  'San Mateo',
#  'Rose Hill',
#  'Azle',
#  'Paradise Valley',
#  'Gilbert',
#  'Coxsackie',
#  'Pine Bluff',
#  'Reading',
#  'Harrison Township',
#  'La Grange Park',
#  'Kalamazoo',
#  'Carson City',
#  'Pauline',
#  'Conneaut',
#  'Pocahontas',
#  'Sausalito',
#  'Bon Air',
#  'Society Hill',
#  'Hightstown',
#  'Bridgeville',
#  'Los Banos',
#  'Easley',
#  'Guilderland',
#  'Tacoma',
#  'Willard',
#  'Perrysburg',
#  'Rock Hill',
#  'Dinuba',
#  'Surprise',
#  'Bolingbrook',
#  'Mount Zion',
#  'Ardsley',
#  'Southport',
#  'Blackshear',
#  'Portland',
#  'Boulder City',
#  'Whittier',
#  'Grosse Pointe',
#  'Oakland',
#  'Frankford',
#  'Hales Corners',
#  'Yuba City',
#  'Oelwein',
#  'Claiborne',
#  'Point Lookout',
#  'Port Orchard',
#  'Pikeville',
#  'Plymouth Meeting',
#  'Perry',
#  'New Canaan',
#  'Teaneck',
#  'Holyoke',
#  'Greensboro',
#  'Palos Hills',
#  'Fort Washington',
#  'Wharton',
#  'Cayucos',
#  'Holmdel',
#  'Palm Harbor',
#  'Louisburg',
#  'Provo',
#  'Norway',
#  'Londonderry',
#  'Las Cruces',
#  'Marrero',
#  'Hephzibah',
#  ...}

# %%
len(inter)
# Out:
# 4159

# %% [markdown]
# Inter shows all cities that are present in both the city locations listed on Twitter and cities in the master list of US cities. With only 4159 cities overlapping, there is clearly some discrepency between the lists on twitter and the master list of cities.

# %%
no_intersection = list(set(df_c) - set(city))

# %%
len(no_intersection)
# Out:
# 1469

# %%
no_intersection
# Out:
# ['Progress',
#  'Grosse Pointe Farms',
#  'Surfside Beach',
#  'Orland Hills',
#  'Fairwood',
#  'King of Prussia',
#  'Middleborough Center',
#  'Blasdell',
#  'Westwood Shores',
#  'Hide-A-Way Lake',
#  'Belville',
#  'Dix Hills',
#  'Indian Shores',
#  'Plandome',
#  'North St Paul',
#  'Scott Township',
#  'Ingalls Park',
#  'Shoreline',
#  'Country Homes',
#  'McKee City',
#  'Buckhall',
#  'Delhi Hills',
#  'Madeira',
#  'North Shore',
#  'Grandview Heights',
#  'Dargin',
#  'Big Coppitt Key',
#  'Fort Carson',
#  'Orange Blossom Hills',
#  'Lake Success',
#  'Security',
#  'McLean',
#  'Blennerhassett',
#  'Harahan',
#  'Clyde Hill',
#  'Green Park',
#  'Neptune City',
#  'Wagon Wheel',
#  'Farmington Hills',
#  'Bull Run',
#  'Walker Mill',
#  'Howland Center',
#  'Avilla Beach',
#  'Agua Fria',
#  'Bells Cross Roads',
#  'Blue Ash',
#  'Ocean Pines',
#  'Sunny Isles Beach',
#  'Lutherville',
#  'Oroville East',
#  'Hoover',
#  'Dale City',
#  'Kendall West',
#  'Dakota Ridge',
#  'St Matthews',
#  'Branchburg',
#  'Pasatiempo',
#  'Phalanx',
#  'Lynnwood-Pricedale',
#  'Picnic Point',
#  'North Haledon',
#  'Edgewater Park',
#  'Cedarwood Park',
#  'Harbison Canyon',
#  'Union Beach',
#  'Ashwaubenon',
#  'Great Neck Plaza',
#  'Bowleys Quarters',
#  'McMurray',
#  'Laurel Hollow',
#  'Castle Hills',
#  'Short Pump',
#  'Tysons Corner',
#  'University City',
#  'Loudoun Valley Estates',
#  "D'Iberville",
#  'Chesterfield Court House',
#  'Halfmoon',
#  'Orcutt',
#  'Upper Brookville',
#  'East Bremerton',
#  'Marina del Rey',
#  'Eatons Neck',
#  'Hidden Meadows',
#  'Setauket',
#  'West Lake Sammamish',
#  'Home Garden',
#  'Frankfort Square',
#  'Northlake',
#  'Withamsville',
#  'Carrollwood',
#  'Sharonville',
#  'West Lawn',
#  'Highlands Ranch',
#  'Dishman',
#  'Dorneyville',
#  'Fort Shawnee',
#  'Crescent Springs',
#  'Thunderbolt',
#  'unspecified',
#  'Davie',
#  'East Lake-Orient Park',
#  'Dranesville',
#  'Vinita Park',
#  'Massac',
#  'Rolling Hills',
#  'Beacon Square',
#  'Garnet',
#  'Catalina Foothills',
#  'Westwood Lakes',
#  'Feather Sound',
#  'Hutchinson Island South',
#  'Travers Corners',
#  'North Snyderville Basin',
#  'Orchard Lake Village',
#  'North Lauderdale',
#  'Boston Heights',
#  'Mystic Island',
#  'East Patchogue',
#  'Oakbrook Terrace',
#  'Meadow Oaks',
#  'Mountain Lake Park',
#  'North Bellport',
#  'Palos Verdes Estates',
#  'Micco',
#  'Lake Magdalene',
#  'Ken Caryl',
#  'Collingdale',
#  'Windcrest',
#  'Olivette',
#  'Chesterbrook',
#  'Pine Castle',
#  'Farmers Branch',
#  'Prunedale',
#  'St Clair Shores',
#  'Whitefish Bay',
#  'Timberlane',
#  'Bayou Blue',
#  'Mount Lebanon',
#  'Lake Arbor',
#  'Devola',
#  'South Russell',
#  'East Porterville',
#  'Cordaville',
#  'Wyndmoor',
#  'Florida City',
#  'St Joseph',
#  'Jupiter Farms',
#  'Greatwood',
#  'River Bluff',
#  'Isle of Hope',
#  'Leon Valley',
#  'South Miami',
#  'East Lake',
#  'Oyster Bay Cove',
#  'Terrytown',
#  'Mokuleia',
#  'McPherson',
#  'White Horse',
#  'Smiths',
#  'Hueytown',
#  'Sanatoga',
#  'Parkland',
#  'Southern Shores',
#  'Garfield Heights',
#  'Cornwall-on-Hudson',
#  'DeKalb',
#  'Douglass Hills',
#  'West Hattiesburg',
#  'Hawaiian Beaches',
#  'Hyson',
#  'East Hemet',
#  'Woodbury Center',
#  'West Carrollton City',
#  'Erlands Point',
#  'Cherry Grove',
#  'Cloverville',
#  'Belleair Bluffs',
#  'Forestbrook',
#  'Fern Creek',
#  'Citrus Ridge',
#  'Hi-Nella',
#  'Norland',
#  'Pike Creek',
#  'Los Altos Hills',
#  'McSherrystown',
#  'Old Jefferson',
#  'Hempfield',
#  'North Bellmore',
#  'Colesville',
#  'Benton Heights',
#  'Kettering',
#  'Shaler Township',
#  'Rosslyn Farms',
#  'West Bay Shore',
#  'Yardley',
#  'Gang Mills',
#  'Town Pump',
#  'Fruit Heights',
#  'Belle Meade',
#  'Lake Mohawk',
#  'New Hempstead',
#  'Walterhill',
#  'Alaska',
#  'Aldine',
#  'Pecan Grove',
#  'Lysander',
#  'Brass Castle',
#  'Daytona Beach Shores',
#  'Sygan',
#  'Spokane Valley',
#  'Edgemere',
#  'Lakeland Heights',
#  "Town 'n' Country",
#  'Sycaway',
#  'Harris Hill',
#  'Dardenne Prairie',
#  'Camp Pendleton North',
#  'West Wood',
#  'Lemoore Station',
#  'Acacia Villas',
#  'Taft Southwest',
#  'Sauk Village',
#  'North Wantagh',
#  'Green Oaks',
#  'Green Haven',
#  'Beach Haven West',
#  'Oak Point',
#  'Muskegon Heights',
#  'McCordsville',
#  'Ten Mile Run',
#  'Wolverine Lake',
#  'Cottonwood West',
#  'Lewisboro',
#  'Aladdin City',
#  'Lochearn',
#  'Temple Terrace',
#  'Raisin',
#  'Cypress Lake',
#  'Highlands-Baywood Park',
#  'Sudden Valley',
#  'Tara Hills',
#  'Winter Gardens',
#  'Des Peres',
#  'Perry Heights',
#  'The Pinery',
#  'Gleneagle',
#  'University Heights',
#  'Lowes Island',
#  'Piney Point Village',
#  'Jacinto City',
#  'Hill Air Force Base',
#  'Halawa',
#  'East Brainerd',
#  'Fairfield Glade',
#  'Robbinsdale',
#  'Citrus Park',
#  'Hedwig Village',
#  'Wollochet',
#  'Sarasota Springs',
#  'Innsbrook',
#  'Rothsville',
#  'Bayonet Point',
#  'East Garden City',
#  'Black Point',
#  'SeaTac',
#  'Mellingertown',
#  'Wyomissing',
#  'Port Vue',
#  'St Peter',
#  'Makakilo',
#  'Viera West',
#  'Chuluota',
#  'Conococheague',
#  'Coto de Caza',
#  'Lindenwold',
#  'South Hempstead',
#  'Fair Oaks Ranch',
#  'Woodlawn Beach',
#  'Walton Park',
#  'Applewood',
#  'Bradford Woods',
#  'Villano Beach',
#  'Ocean Acres',
#  'Countryside',
#  'Searingtown',
#  'Towamensing Trails',
#  'Bermuda Dunes',
#  'Estelle',
#  'La Crescenta-Montrose',
#  'Waggaman',
#  'North Lindenhurst',
#  'Spotsylvania Courthouse',
#  'The Acreage',
#  'South St Paul',
#  'Annapolis Neck',
#  'Port St John',
#  'San Antonio Heights',
#  'Tamarac',
#  'Old Jamestown',
#  'Buenaventura Lakes',
#  'Byram Center',
#  'DeQuincy',
#  'La Riviera',
#  'New Cassel',
#  'Lake Murray of Richland',
#  'Merriam',
#  'The Village',
#  'New Territory',
#  'Reserve Township',
#  'Hill Country Village',
#  'Maple Grove',
#  'Glenn Heights',
#  'Euharlee',
#  'McHenry',
#  'Walkers Forge',
#  'Bemiss',
#  'Parma Heights',
#  'West Hazleton',
#  'Pigeon Creek',
#  'Laflin',
#  'Ho-Ho-Kus',
#  'East Ridge',
#  'Patterson Township',
#  'Central Park',
#  'Irondequoit',
#  'Waimanalo Beach',
#  'East Milton',
#  'White Bear Lake',
#  'San Castle',
#  'Fox Chase',
#  'Sand Hill',
#  'Middleburg Heights',
#  'Sunset Hills',
#  'Fort Hamer',
#  'Bamford',
#  'Oakbrook',
#  'West Little River',
#  'St Michael',
#  'Decker Prairie',
#  'Brown Deer',
#  'Dalworthington Gardens',
#  'Milwaukie',
#  'Asharoken',
#  'Cinco Ranch',
#  'Hunters Creek',
#  'Bostonia',
#  'Cayuga Heights',
#  'South Brunswick',
#  'Lauderhill',
#  'Coral Hills',
#  'Bluffdale',
#  'Bay St Louis',
#  'North Seekonk',
#  'Vadnais Heights',
#  "O'Neill",
#  'Churchill',
#  'Laplace',
#  'San Carlos Park',
#  'South Greensburg',
#  'Casas Adobes',
#  'Jacksonwald',
#  'New Square',
#  'Tamalpais Valley',
#  'Summerside',
#  'Fond du Lac',
#  'Shark River Hills',
#  'West Slope',
#  'East Ithaca',
#  'Bithlo',
#  'Gulf Park Estates',
#  'North Decatur',
#  'Five Forks',
#  'Lakes by the Bay',
#  'St Pete Beach',
#  'Honalo',
#  'Croton-on-Hudson',
#  'Downer',
#  'Cutler Bay',
#  'Birch Bay',
#  'St Marys',
#  'Eastmont',
#  'Village of the Branch',
#  'Green Knoll',
#  'Landen',
#  'Waikoloa Village',
#  'Florida Ridge',
#  'McKinleyville',
#  'Pine Hills',
#  'St Cloud',
#  'Havre de Grace',
#  'Corona de Tucson',
#  'Roeland Park',
#  'Cloverleaf',
#  'West Odessa',
#  'Trophy Club',
#  'Timberwood Park',
#  'St James',
#  'Huber Heights',
#  'Dakota Dunes',
#  'North Lakeport',
#  'Whispering Pines',
#  'Granite Shoals',
#  'Silver Firs',
#  'McKees Rocks',
#  'Madison Park',
#  'West Carson',
#  'Lyncourt',
#  'East Hills',
#  'Lake St Louis',
#  'River Ridge',
#  'Hurstbourne Acres',
#  'Richmond West',
#  'Dover Beaches South',
#  'Pantops',
#  'Cheektowaga',
#  'Rye Brook',
#  'Calumet Park',
#  'Dalton Gardens',
#  'West Valley City',
#  'Pasadena Hills',
#  'Sea Bright',
#  'Masonboro',
#  'Opportunity',
#  'Desloge',
#  'Sudley',
#  'Finneytown',
#  'Burr Ridge',
#  'Hornsby Bend',
#  'Riverdale Park',
#  'North Ogden',
#  'Lexington Hills',
#  'Pebble Creek',
#  'Bushnell Basin',
#  'Cardiff',
#  'Nanakuli',
#  'Krugerville',
#  'Fife',
#  'Kenmar',
#  'South Euclid',
#  'George Mason',
#  'Chevy Chase Village',
#  'Santa Rosa Valley',
#  'Round Lake Beach',
#  'Cinnaminson',
#  'Orangetree',
#  'Makaha',
#  'Camp Springs',
#  'Princeton Meadows',
#  'Fish Hawk',
#  'Felida',
#  'Mission Bend',
#  "Lee's Summit",
#  'Poinciana',
#  'Chevy Chase View',
#  'Sherrelwood',
#  'Mint Hill',
#  'Butte des Morts',
#  'Shively',
#  'Fuquay-Varina',
#  'St Helens',
#  'June Park',
#  'Deephaven',
#  'Del City',
#  'North Randall',
#  'North Valley',
#  'Forrester',
#  'Upper Grand Lagoon',
#  'Foothill Farms',
#  'Bee Ridge',
#  'Highview',
#  'Belvedere Park',
#  'Hills and Dales',
#  'Southchase',
#  'Washington Heights',
#  'Poipu',
#  'Taylor Mill',
#  'South Corning',
#  'Anderson Mill',
#  'Atascocita',
#  'Butler Beach',
#  'Pretty Bayou',
#  'La Presa',
#  'Erlton',
#  'Wilkins Township',
#  'Bonadelle Ranchos',
#  'Lake Wylie',
#  'Fort Myers Shores',
#  'Joint Base Lewis-McChord',
#  'Ballenger Creek',
#  'Vinings',
#  'East Freehold',
#  'La Habra Heights',
#  'Kenneth City',
#  'Shell Point',
#  'Haddon',
#  'Tigard',
#  'Medley',
#  'Ormond-by-the-Sea',
#  'Aspen Hill',
#  'Dormont',
#  'Viera East',
#  'Hamilton Square',
#  'Woodsburgh',
#  'Klahanie',
#  'Nassau Bay',
#  'Baxter Estates',
#  'Hawthorn Woods',
#  'Madison Center',
#  'Travis Ranch',
#  'Lake Lorraine',
#  'Meiners Oaks',
#  'Shady Hills',
#  'Fort Polk South',
#  'West Pittston',
#  'Lakewood Ranch',
#  'Neuse Forest',
#  'West Seneca',
#  'West Glens Falls',
#  'Mount Olympus',
#  'Grosse Pointe Park',
#  'Northview',
#  'Casa Conejo',
#  'Manhasset Hills',
#  'Spreckelsville',
#  'Country Club',
#  'Maple Glen',
#  'Comstock Northwest',
#  'La Huerta',
#  'Hapeville',
#  'The Crossings',
#  'Florence-Graham',
#  'Lake Buena Vista',
#  'Martha Lake',
#  'Midwest City',
#  'East York',
#  'Panthersville',
#  'DeLand Southwest',
#  'Tega Cay',
#  'Lake Ridge',
#  'Crosspointe',
#  'DuBois',
#  'Mays Chapel',
#  'Cape St Claire',
#  'Oildale',
#  'Middleburg-Clay Hill',
#  'Warminster Heights',
#  'Palma Sola',
#  'Monmouth Hills',
#  'Wood-Ridge',
#  'Union Park',
#  'Green Brook',
#  'Ko Olina',
#  'Fort Wright',
#  'Lake Wildwood',
#  'Lakeway',
#  'LaGrange',
#  'North York',
#  'North Bay Village',
#  'Woodlynne',
#  'Summerlin South',
#  'Opal Cliffs',
#  'Fernway',
#  'St Charles',
#  'Coral Gardens',
#  'Heritage Hills',
#  'Adair Village',
#  'Marble Cliff',
#  'White Center',
#  'McCandless',
#  'Hazel Dell South',
#  'Boulevard Park',
#  'Keowee',
#  'Mayflower Village',
#  'Mount Vista',
#  'Grosse Pointe Shores',
#  'Bayou Cane',
#  'Fairview Lanes',
#  'Mountain House',
#  'North Beach Haven',
#  'Wyndham',
#  'Seven Corners',
#  'Lino Lakes',
#  'North Puyallup',
#  'West Marion',
#  'Cloverly',
#  'Goulding',
#  'Selmont',
#  'St Augustine',
#  'Contra Costa Centre',
#  'Beechwood',
#  'North Patchogue',
#  'Ahuimanu',
#  'Lake Forest Park',
#  'Glenvar Heights',
#  'West Plattsburgh',
#  'Maili',
#  'North Plainfield',
#  'West Bountiful',
#  'Green Hill',
#  'Weweantic',
#  'South Gastonia',
#  'Ladera Heights',
#  'Aventura',
#  'Cooper City',
#  'Saks',
#  'North Weeki Wachee',
#  'El Jebel',
#  'Mountain Brook',
#  'Tellico Village',
#  'Taylortown',
#  'Canterwood',
#  'Fountainebleau',
#  'Inglewood-Finn Hill',
#  'Madeira Beach',
#  'Willow Oak',
#  "O'Hara Township",
#  'Bardmoor',
#  'Cottage Lake',
#  'Rio Pinar',
#  'Baldwin Harbor',
#  'Burns Harbor',
#  'Timber Pines',
#  'Aspen Grove',
#  'Bee Cave',
#  'North Barrington',
#  'Hastings-on-Hudson',
#  'East Grand Rapids',
#  'Terrell Hills',
#  'Sunrise Lake',
#  "Sullivan's Island",
#  'Sunrise Manor',
#  'Munhall',
#  'Temescal Valley',
#  'Ojus',
#  'Tonka Bay',
#  'Ewa Gentry',
#  'Saw Creek',
#  'East Foothills',
#  'Harbor',
#  'South Valley',
#  'Seven Oaks',
#  'Saginaw Township North',
#  'Lago Vista',
#  'Bloomfield Township',
#  'Seat Pleasant',
#  'Skippers Corner',
#  'Mariemont',
#  'South Apopka',
#  'Gulf Hills',
#  'Municipality of Monroeville',
#  'Miami Shores',
#  "Bailey's Crossroads",
#  'Crestwood Village',
#  'Crystal Lake Park',
#  'West Freehold',
#  'Swissvale',
#  'Anthem',
#  'Littleton Common',
#  'Seven Trees',
#  'Gandy',
#  'Dentsville',
#  'Bal Harbour',
#  'Samoset',
#  'Naval Base Kitsap',
#  'Washington Terrace',
#  'East Farmingdale',
#  'South Whittier',
#  'Cedar Hills',
#  'Jollyville',
#  'St Ann',
#  'Tarrant',
#  'Copley',
#  'Carol City',
#  'Shadow Lake',
#  'Mountain View Acres',
#  'Port St Lucie',
#  'Johns Creek',
#  'River Park',
#  'Hialeah Gardens',
#  'Westworth Village',
#  'Oak Hills Place',
#  'Trotwood',
#  'St Paul',
#  'Jasmine Estates',
#  'Ramtown',
#  'Vandenberg Air Force Base',
#  'Kronenwetter',
#  'North Zanesville',
#  'Lower Grand Lagoon',
#  'Rotterdam',
#  'Desoto Lakes',
#  'Bridgetown North',
#  'East Lexington',
#  'Municipality of Murrysville',
#  'Upper Arlington',
#  'Fearrington Village',
#  'Upper Providence Township',
#  'Scenic Oaks',
#  'Alderwood Manor',
#  'Fairport Harbor',
#  'North Syracuse',
#  'Eddystone',
#  'Rancho Calaveras',
#  'Pimmit Hills',
#  'Braden River',
#  'Northglenn',
#  'Kaneohe Station',
#  'Barnstable Town',
#  'Plat',
#  'Chalkville',
#  'Crafton',
#  'North Chevy Chase',
#  'St Johns',
#  'West Pensacola',
#  'Gold River',
#  'North Bay Shore',
#  'Del Monte Forest',
#  'Normandy Park',
#  'Sault Ste Marie',
#  'Noank',
#  'Miami Springs',
#  'Arbutus',
#  'Tanglewilde',
#  'Stonegate',
#  'Boulder Hill',
#  'Cedar Glen West',
#  'Lealman',
#  'Gages Lake',
#  'West Belmar',
#  'South Laurel',
#  'McLeansville',
#  'Middle Valley',
#  'White House Station',
#  'Upper St Clair',
#  'Blackhawk',
#  'North Caldwell',
#  'DeWitt',
#  'Ensley',
#  'Chili Center',
#  'Hideaway',
#  'Roosevelt Park',
#  'Idylwood',
#  'East Norriton',
#  'Obetz',
#  'Jersey Village',
#  'Cheval',
#  'Turnersville',
#  'South Hooksett',
#  'Brookmont',
#  'Medford Farms',
#  'Granite Hills',
#  'Merritt Park',
#  'Mount Penn',
#  'Tucson Estates',
#  'Tinton Falls',
#  'Paw Paw Lake',
#  'Robinson Township',
#  'Alamo Heights',
#  'Pelham Manor',
#  'Rhea Mills',
#  'Nichols Hills',
#  "Sewall's Point",
#  'Cutlerville',
#  'Smokey Point',
#  'Urbancrest',
#  'Lake Ronkonkoma',
#  'West Norriton',
#  'French Valley',
#  'Sugarland Run',
#  'North New Hyde Park',
#  'Wormleysburg',
#  'Rancho San Diego',
#  'El Lago',
#  'Glen Raven',
#  'Foxborough',
#  'Jurupa Valley',
#  'Gearhart',
#  'Napili-Honokowai',
#  'Winston-Salem',
#  'Lake Barcroft',
#  'Konterra',
#  'Worthington Hills',
#  'Spring Valley Village',
#  'North Gates',
#  'East Shoreham',
#  'West Wyomissing',
#  'Adamston',
#  'Fircrest',
#  'Gunbarrel',
#  'Edgeworth',
#  'Heritage Creek',
#  'Siesta Key',
#  'Eden Isle',
#  'Old Tappan',
#  'Ben Avon Heights',
#  'East Los Angeles',
#  'Indian Harbour Beach',
#  'McFarland',
#  'La Vale',
#  'Beckett',
#  'Bellview',
#  'Holden Heights',
#  'Spackenkill',
#  'Maple Bluff',
#  'Little Canada',
#  'Hillcrest Heights',
#  'Celebration',
#  'Elliotts Bluff',
#  'Billington Heights',
#  'Lower Burrell',
#  'Willoughby Hills',
#  'Long Hill',
#  'East Palo Alto',
#  'Chillum',
#  'Choctaw Lake',
#  'Tortolita',
#  'Lake of the Woods',
#  'Edgewater Beach',
#  'Old Saybrook Center',
#  'St Petersburg',
#  'Aloha',
#  'Graymoor-Devondale',
#  'Plymouth Township',
#  'Fife Heights',
#  'Valinda',
#  'Lantana',
#  'Wescosville',
#  'Castle Shannon',
#  'West Lake Stevens',
#  'Upper Nyack',
#  'Overlea',
#  'Tequesta',
#  'Detroit Beach',
#  'Highland Heights',
#  'Village Green',
#  'Doctor Phillips',
#  'Ladue',
#  'Inkerman',
#  'Houston Acres',
#  'World Golf Village',
#  'Fountainhead-Orchard Hills',
#  'Sugar Bush Knolls',
#  'Highland Beach',
#  'Rolling Fields',
#  'San Diego Country Estates',
#  'Hickory Creek',
#  'Ship Bottom',
#  'Norton Shores',
#  'Kings Point',
#  'Channel Islands Beach',
#  'Doraville',
#  'Sienna Plantation',
#  'Topanga Beach',
#  'Wake Village',
#  'Oakland Park',
#  'Turpin Hills',
#  'Herricks',
#  'Meadow Lake',
#  'Seven Hills',
#  'Piney Green',
#  'Belle Isle',
#  'Lake Mohegan',
#  'Cross Lanes',
#  'Del Aire',
#  'South Yuba City',
#  'Miami Lakes',
#  'Isle of Palms',
#  'Cañon City',
#  'Fairview Park',
#  'Overland',
#  'College',
#  'Bunker Hill Village',
#  'North Potomac',
#  'Orchard Mesa',
#  'Skidaway Island',
#  'West Miami',
#  'Roslyn Harbor',
#  'Florin',
#  'Archdale',
#  'Bell Acres',
#  'Brinckerhoff',
#  'Crescent City North',
#  'Lakeside Park',
#  'Trainer',
#  'Egypt Lake-Leto',
#  'Fox Point',
#  'Murrieta Hot Springs',
#  'Joppatowne',
#  'Biscayne Park',
#  'Seaville',
#  'Ocean Ridge',
#  'Isla Vista',
#  'Fellsburg',
#  'Summit Park',
#  'Greenburgh',
#  'St Martin',
#  'North Utica',
#  'Pine Island Ridge',
#  'Upper Saddle River',
#  'Lackawanna',
#  'Lake Shore',
#  'The Village of Indian Hill',
#  'Highland Haven',
#  'Berry Hill',
#  'Eldorado at Santa Fe',
#  'Eastampton',
#  'Leisure City',
#  'Forest Glen',
#  'Myrtle Grove',
#  'Holiday City South',
#  'Pupukea',
#  'Bay Head',
#  "Land O' Lakes",
#  'Battlefield',
#  'South Bradenton',
#  'Weeki Wachee',
#  'Austintown',
#  'Watermill',
#  'East Perrine',
#  'McNair',
#  'Moreland Hills',
#  'East Hill-Meridian',
#  'Cleveland Heights',
#  'Gardnerville Ranchos',
#  'Burien',
#  'Eldersburg',
#  'LaSalle',
#  'Naples Park',
#  'West Athens',
#  'Rolling Hills Estates',
#  'Cecil-Bishop',
#  'Oak Ridge North',
#  'Meadow Woods',
#  'Dixon Corner',
#  'Heeia',
#  'Union Gap',
#  'Heathrow',
#  'Woodport',
#  'Moss Bluff',
#  'Fern Park',
#  'Waimalu',
#  'Brooklyn Park',
#  'Dunwoody',
#  'Herbertsville',
#  'Juno Beach',
#  'Navy Yard City',
#  'Manalapan',
#  'Country Walk',
#  'Tiburon',
#  'Hurstbourne',
#  'Bellmead',
#  'Garden City South',
#  'Minnetrista',
#  'Avocado Heights',
#  'Texas',
#  'White Settlement',
#  'St Albans',
#  'Serenada',
#  'Colonie',
#  'Onion Creek',
#  'Coral Terrace',
#  'St Andrews',
#  'Limestone Creek',
#  'Hainesville',
#  'Kinnelon',
#  'Hillvale',
#  'Moores Mill',
#  'Boca Ciega',
#  'Eglin Air Force Base',
#  'Raytown',
#  'Cascades',
#  'Eastvale',
#  'Shaker Heights',
#  'Shorewood Hills',
#  'McKinney',
#  'Village of Clarkston',
#  'Mount Helix',
#  'Cahaba Heights',
#  'Wailea',
#  'East Millcreek',
#  'Cypress Gardens',
#  'Courtdale',
#  'Wauwatosa',
#  'Hazel Dell North',
#  'Biltmore Forest',
#  'Lakeland Village',
#  'West Reading',
#  'Peppermill Village',
#  'West Clarkston-Highland',
#  'Seabreeze',
#  'Parole',
#  'Geneva-on-the-Lake',
#  'Radnor Township',
#  'Lake Lucerne',
#  'Toftrees',
#  'Sandusky South',
#  'Hawk Cove',
#  'Ogden Dunes',
#  'West Goshen',
#  ...]

# %% [markdown]
# No_intersection shows every city listed as a location on twitter that was not found in our master list of US cities. Looking through a number of these 'cities' that were found on Twitter but not on the master list revealed that many were either neighborhoods or 'census designated places'. 'Census designated places' or cdp's are unincorporated communities who may have a colloquial name but only legally exist for census collection purposes. They are not self-governing municipalities and thus would not appear on a list of US cities. Likewise, neighborhoods of major cities may act as common reference for where someone lives, but they rarely have their own administrations separate from the cities they are located within.

# %%
check = set(city).intersection(no_intersection)

# %%
check
# Out:
# set()

# %% [markdown]
# We no longer have any intersecting cities between our two sets of cities.
